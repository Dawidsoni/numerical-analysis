# %% [markdown]
# # Wyznaczanie wartości liczby π
#
# Poniższe przykłady ilustrują liczbę uzyskanych poprawnych cyfr przybliżenia π w zależności od użytej metody oraz liczby iteracji lub czasu.

# %%
include("program.jl")
# Out:
# chudnovsky (generic function with 1 method)

# %% [markdown]
# ### 1. Szereg Leibniza

# %%
computeIterPi(leibniz, 100000, 10000)
println()
computeTimePi(leibniz, 5000, 500)
# Out:
# Po 10000 iteracjach: 3
# Po 20000 iteracjach: 4
# Po 30000 iteracjach: 4
# Po 40000 iteracjach: 4
# Po 50000 iteracjach: 4
# Po 60000 iteracjach: 4
# Po 70000 iteracjach: 4
# Po 80000 iteracjach: 4
# Po 90000 iteracjach: 4
# Po 100000 iteracjach: 4
#
# Po 500 milisekundach: 4
# Po 1000 milisekundach: 5
# Po 1500 milisekundach: 5
# Po 2000 milisekundach: 5
# Po 2500 milisekundach: 5
# Po 3000 milisekundach: 5
# Po 3500 milisekundach: 5
# Po 4000 milisekundach: 5
# Po 4500 milisekundach: 5
# Po 5000 milisekundach: 5
# 3.141593547007715380486119819023525050507187143475327377816437641182934181141135

# %% [markdown]
# ### 2. Szereg Newtona-Eulera

# %%
computeIterPi(newtonEuler, 100000, 10000)
println()
computeTimePi(newtonEuler, 5000, 500)
# Out:
# Po 10000 iteracjach: 3
# Po 20000 iteracjach: 3
# Po 30000 iteracjach: 4
# Po 40000 iteracjach: 4
# Po 50000 iteracjach: 4
# Po 60000 iteracjach: 4
# Po 70000 iteracjach: 4
# Po 80000 iteracjach: 4
# Po 90000 iteracjach: 4
# Po 100000 iteracjach: 4
#
# Po 500 milisekundach: 9
# Po 1000 milisekundach: 10
# Po 1500 milisekundach: 10
# Po 2000 milisekundach: 4
# Po 2500 milisekundach: 10
# Po 3000 milisekundach: 11
# Po 3500 milisekundach: 11
# Po 4000 milisekundach: 5
# Po 4500 milisekundach: 5
# Po 5000 milisekundach: 11
# 3.141592653591249000806315640964345584976056188954435486124892146912306092166016

# %% [markdown]
# ### 3. Metoda Monte Carlo

# %%
computeIterPi(monteCarlo, 100000, 10000)
println()
computeTimePi(monteCarlo, 5000, 500)
# Out:
# Po 10000 iteracjach: 1
# Po 20000 iteracjach: 2
# Po 30000 iteracjach: 2
# Po 40000 iteracjach: 2
# Po 50000 iteracjach: 2
# Po 60000 iteracjach: 2
# Po 70000 iteracjach: 2
# Po 80000 iteracjach: 1
# Po 90000 iteracjach: 1
# Po 100000 iteracjach: 1
#
# Po 500 milisekundach: 2
# Po 1000 milisekundach: 2
# Po 1500 milisekundach: 2
# Po 2000 milisekundach: 2
# Po 2500 milisekundach: 2
# Po 3000 milisekundach: 2
# Po 3500 milisekundach: 2
# Po 4000 milisekundach: 3
# Po 4500 milisekundach: 3
# Po 5000 milisekundach: 2
# 3.142424798036586470384222001807012001829102613098407046021370457341925108409672

# %% [markdown]
# ### 4. Szereg Nilakanthy

# %%
computeIterPi(nilakantha, 100000, 10000)
println()
computeTimePi(nilakantha, 5000, 500)
# Out:
# Po 10000 iteracjach: 12
# Po 20000 iteracjach: 13
# Po 30000 iteracjach: 13
# Po 40000 iteracjach: 14
# Po 50000 iteracjach: 14
# Po 60000 iteracjach: 14
# Po 70000 iteracjach: 14
# Po 80000 iteracjach: 15
# Po 90000 iteracjach: 15
# Po 100000 iteracjach: 15
#
# Po 500 milisekundach: 15
# Po 1000 milisekundach: 16
# Po 1500 milisekundach: 16
# Po 2000 milisekundach: 17
# Po 2500 milisekundach: 17
# Po 3000 milisekundach: 17
# Po 3500 milisekundach: 17
# Po 4000 milisekundach: 17
# Po 4500 milisekundach: 18
# Po 5000 milisekundach: 18
# 3.141592653589793238748450523200214680648763418489630210193908413531492067675365

# %% [markdown]
# ### 5. Przekształcenie Nilakanthy szeregu Leibniza

# %%
setprecision(250000)
computeIterPi(leibnizTrans, 5000, 500)
println()
computeTimePi(leibnizTrans, 5000, 500)
# Out:
# Po 500 iteracjach: 566
# Po 1000 iteracjach: 1132
# Po 1500 iteracjach: 1697
# Po 2000 iteracjach: 2262
# Po 2500 iteracjach: 2827
# Po 3000 iteracjach: 3393
# Po 3500 iteracjach: 3958
# Po 4000 iteracjach: 4523
# Po 4500 iteracjach: 5088
# Po 5000 iteracjach: 5653
#
# Po 500 milisekundach: 6997
# Po 1000 milisekundach: 14057
# Po 1500 milisekundach: 19800
# Po 2000 milisekundach: 25905
# Po 2500 milisekundach: 31309
# Po 3000 milisekundach: 37485
# Po 3500 milisekundach: 42521
# Po 4000 milisekundach: 48449
# Po 4500 milisekundach: 54161
# Po 5000 milisekundach: 59349
# 3....

# %% [markdown]
# ### 6. Szereg Ramanujana

# %%
setprecision(250000)
computeIterPi(ramanujan, 5000, 500)
println()
computeTimePi(ramanujan, 5000, 500)
# Out:
# Po 500 iteracjach: 3999
# Po 1000 iteracjach: 7990
# Po 1500 iteracjach: 11982
# Po 2000 iteracjach: 15973
# Po 2500 iteracjach: 19964
# Po 3000 iteracjach: 23956
# Po 3500 iteracjach: 27947
# Po 4000 iteracjach: 31938
# Po 4500 iteracjach: 35929
# Po 5000 iteracjach: 39921
#
# Po 500 milisekundach: 2434
# Po 1000 milisekundach: 4621
# Po 1500 milisekundach: 7264
# Po 2000 milisekundach: 9874
# Po 2500 milisekundach: 12445
# Po 3000 milisekundach: 14712
# Po 3500 milisekundach: 17370
# Po 4000 milisekundach: 19876
# Po 4500 milisekundach: 22144
# Po 5000 milisekundach: 24594
# 3....

# %% [markdown]
# ### 7.  Szereg braci Chudnovsky

# %%
setprecision(250000)
computeIterPi(chudnovsky, 5000, 500)
println()
computeTimePi(chudnovsky, 5000, 500)
# Out:
# Po 500 iteracjach: 7105
# Po 1000 iteracjach: 14195
# Po 1500 iteracjach: 21286
# Po 2000 iteracjach: 28377
# Po 2500 iteracjach: 35468
# Po 3000 iteracjach: 42559
# Po 3500 iteracjach: 49650
# Po 4000 iteracjach: 56741
# Po 4500 iteracjach: 63832
# Po 5000 iteracjach: 70922
#
# Po 500 milisekundach: 722
# Po 1000 milisekundach: 1375
# Po 1500 milisekundach: 2041
# Po 2000 milisekundach: 2623
# Po 2500 milisekundach: 3261
# Po 3000 milisekundach: 3857
# Po 3500 milisekundach: 4864
# Po 4000 milisekundach: 6055
# Po 4500 milisekundach: 7261
# Po 5000 milisekundach: 8494
# 3....

# %% [markdown]
# ### 8. Przekształcenie Nilakanthy szeregu Newtona-Eulera

# %%
setprecision(250000)
computeIterPi(newtonTrans, 5000, 500)
println()
computeTimePi(newtonTrans, 5000, 500)
# Out:
# Po 500 iteracjach: 567
# Po 1000 iteracjach: 1132
# Po 1500 iteracjach: 1697
# Po 2000 iteracjach: 2262
# Po 2500 iteracjach: 2828
# Po 3000 iteracjach: 3393
# Po 3500 iteracjach: 3958
# Po 4000 iteracjach: 4523
# Po 4500 iteracjach: 5088
# Po 5000 iteracjach: 5654
#
# Po 500 milisekundach: 6215
# Po 1000 milisekundach: 13061
# Po 1500 milisekundach: 19999
# Po 2000 milisekundach: 26490
# Po 2500 milisekundach: 32002
# Po 3000 milisekundach: 37754
# Po 3500 milisekundach: 44812
# Po 4000 milisekundach: 52219
# Po 4500 milisekundach: 59431
# Po 5000 milisekundach: 66916
# 3....
